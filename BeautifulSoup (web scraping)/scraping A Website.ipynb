# %% [markdown]
# # Web Scraping a Real Website

# %%
from bs4 import BeautifulSoup
import requests

# %%
# get() method from requests
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=')
print(html_text)
# Out:
# <Response [200]>

# %%
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup = BeautifulSoup(html_text, 'lxml')
job = soup.find('li', class_ = 'clearfix job-bx wht-shd-bx')
print(job)
# Out:
# <li class="clearfix job-bx wht-shd-bx">
# <header class="clearfix">
# <!--
# -->
# <!-- -->
# <h2>
# <a href="https://www.timesjobs.com/job-detail/python-radical-tecnologies-cochin-kochi-ernakulam-thiruvananthapuram-thrissur-7-to-12-yrs-jobid-bUxdpY7jo5dzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','69380643','PYTHON SCRIPTING  ,  PYTHON  ,  FULLSTACK  PYTHON','Cochin/ Kochi/ Ernakulam,  Thiruvananthapuram,  Thrissur','7 - 12','IT Software : Software Products &amp; Services','1' )" target="_blank">
#       "<strong class="blkclor">PYTHON</strong>"</a> </h2>
# <h3 class="joblist-comp-name">
#     Radical Tecnologies
#      <span class="comp-more">(<a class="jobs-frm-comp" href="/candidate/companySearchResult.html?from=submit&amp;encid=kPl7Yzee5cPTJdhHim03gg==&amp;searchType=byCompany&amp;luceneResultSize=25">More Jobs</a>) </span>
# </h3>
# </header>
# <ul class="top-jd-dtl clearfix">
# <li><i class="material-icons">card_travel</i>7 - 12 yrs</li>
# ...

# %%
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup = BeautifulSoup(html_text, 'lxml')
job = soup.find('li', class_ = 'clearfix job-bx wht-shd-bx')
company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace(' ','')
print(company_name)
# Out:
# RadicalTecnologies
# (MoreJobs)

# %%
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup = BeautifulSoup(html_text, 'lxml')
job = soup.find('li', class_ = 'clearfix job-bx wht-shd-bx')
company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace(' ','')
skills = job.find('span', class_ = 'srp-skills').text.replace(' ','')
print(skills)
# Out:
# "PYTHONSCRIPTING","PYTHON","FULLSTACKPYTHON"

# %%
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup = BeautifulSoup(html_text, 'lxml')
job = soup.find('li', class_ = 'clearfix job-bx wht-shd-bx')
company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace(' ','')
skills = job.find('span', class_ = 'srp-skills').text.replace(' ','')
print(f"""
Company Name: \n {company_name}
Required Skills:{skills}
""")
# Out:
# Company Name:
#
# RadicalTecnologies
# (MoreJobs)
#
# Required Skills:
#
# "PYTHONSCRIPTING","PYTHON","FULLSTACKPYTHON"

# %%
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup = BeautifulSoup(html_text, 'lxml')
job = soup.find('li', class_ = 'clearfix job-bx wht-shd-bx')
company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace(' ','')
skills = job.find('span', class_ = 'srp-skills').text.replace(' ','')
published_date = job.find('span', class_ = 'sim-posted')
print(published_date)
# Out:
# <span class="sim-posted">
# <span class="jobs-status covid-icon clearfix">
# <i class="covid-home-icon"></i>Work from Home
# 		    	</span>
# <span>Posted few days ago</span>
# </span>

# %%
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup = BeautifulSoup(html_text, 'lxml')
job = soup.find('li', class_ = 'clearfix job-bx wht-shd-bx')
company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace(' ','')
skills = job.find('span', class_ = 'srp-skills').text.replace(' ','')
published_date = job.find('span', class_ = 'sim-posted').find_next('span').find_next('span').text
print(published_date)
# Out:
# Posted few days ago

# %%
# how to get all job post with published_data posted a few days ago
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup = BeautifulSoup(html_text, 'lxml')
jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')

for job in jobs:
    
    company_name = job.find('h3', class_ = 'joblist-comp-name').text.replace(' ','')
    skills = job.find('span', class_ = 'srp-skills').text.replace(' ','')
    published_date = job.find('span', class_ = 'sim-posted').find_next('span').find_next('span').text
    print(published_date)
    
    print(f"""
    Company Name: \n {company_name}
    Required Skills:{skills}
    """)
    print('')
# Out:
# Posted few days ago
#
#     Company Name:
#
# RadicalTecnologies
# (MoreJobs)
#
#     Required Skills:
#
# "PYTHONSCRIPTING","PYTHON","FULLSTACKPYTHON"
#
#
#
#
# (More Jobs)
#
#     Company Name:
#
# SuryaInformaticsSolutionsPvt.Ltd.
#
#
#     Required Skills:
# python,webtechnologies,linux,mobile,mysql,angularjs,javascript
#
#
#
#
# (More Jobs)
#
#     Company Name:
#
# learntek
# (MoreJobs)
#
#     Required Skills:
# Python
#
#
#
# Bengaluru / Bangalore
#
#     Company Name:
#
# ERMPlacementServicesPvt.Ltd.
# (MoreJobs)
#
#     Required Skills:
# Python,sql
#
#
#
#
# Kolkata
#
#     Company Name:
#
# PerfiosSoftware
#
#
#     Required Skills:
# python,java,scala
#
#
#
#
# Chennai
#
#     Company Name:
#
# IvanInfotechPvt.Ltd.
#
#
#     Required Skills:
#
# rest,python,security,debugging
#
#
#
#
# Gurgaon
#
#     Company Name:
#
# TriadssTechSolutions
#
#
#     Required Skills:
# python,django,html5,javascript
#
#
#
#
# Kolkata
#
#     Company Name:
#
# GEMINISOFTWARESOLUTIONS
#
#
# ...

# %%
# how to get all job post with published_data posted a few days ago
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup = BeautifulSoup(html_text, 'lxml')
jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')
for job in jobs:
    
    published_date = job.find('span', class_ = 'sim-posted').text
    if 'few' in published_date:
        company_name = job.find('h3', class_ = 'joblist-comp-name').text
        skills = job.find('span', class_ = 'srp-skills').text.replace('  , ',',').replace('    ','')
        print('Job Post \n')
        print(f"Company Name: {company_name.strip()}") 
        print(f"Required Skills: {skills.strip()}")
        print('')
# Out:
# Job Post
#
# Company Name: Radical Tecnologies
#      (More Jobs)
# Required Skills: "PYTHON SCRIPTING", "PYTHON", "FULLSTACK  PYTHON"
#
# Job Post
#
# Company Name: Surya Informatics Solutions Pvt. Ltd.
# Required Skills: python, web technologies, linux, mobile, mysql, angularjs, javascript
#
# Job Post
#
# Company Name: learntek
#      (More Jobs)
# Required Skills: Python
#
# Job Post
#
# Company Name: Ivan Infotech Pvt. Ltd.
# Required Skills: rest, python, security, debugging
#
# Job Post
#
# Company Name: east india securities ltd.
# Required Skills: python, hadoop, machine learning
#
# Job Post
#
# Company Name: TandA HR Solutions
# Required Skills: python, git, django,  GIT Hub
#
# Job Post
#
# Company Name: TandA HR Solutions
# Required Skills: Python,  Django,  Flask,  GIT Hub
#
# Job Post
#
# Company Name: art technology and software india pvt ltd
# Required Skills: rest, python, database, django, api
#
# Job Post
#
# Company Name: sjain ventures
# ...

# %%
# get more info link for each recent job post
html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup = BeautifulSoup(html_text, 'lxml')
jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')
for job in jobs:
    
    published_date = job.find('span', class_ = 'sim-posted').text
    if 'few' in published_date:
        company_name = job.find('h3', class_ = 'joblist-comp-name').text
        skills = job.find('span', class_ = 'srp-skills').text.replace('  , ',',').replace('    ','')
        more_info = job.header.h2.a['href']
        print(f"Company Name: {company_name.strip()}") 
        print(f"Required Skills: {skills.strip()}")
        print(f"More Info: {more_info}")
        print('')
# Out:
# Company Name: Radical Tecnologies
#      (More Jobs)
# Required Skills: "PYTHON SCRIPTING", "PYTHON", "FULLSTACK  PYTHON"
# More Info: https://www.timesjobs.com/job-detail/python-radical-tecnologies-cochin-kochi-ernakulam-thiruvananthapuram-thrissur-7-to-12-yrs-jobid-bUxdpY7jo5dzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name: Surya Informatics Solutions Pvt. Ltd.
# Required Skills: python, web technologies, linux, mobile, mysql, angularjs, javascript
# More Info: https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name: learntek
#      (More Jobs)
# Required Skills: Python
# More Info: https://www.timesjobs.com/job-detail/python-faculty-learntek-bengaluru-bangalore-chennai-hyderabad-secunderabad-vijayawada-visakhapatnam-2-to-7-yrs-jobid-K4__PLUS__N8nfOlV5zpSvf__PLUS__uAgZw==&source=srp
#
# Company Name: Ivan Infotech Pvt. Ltd.
# ...

# %%
# filter job post with users skills
# get more info link for each recent job post

print("Put some skill that you are not familiar with")
unfamiliar_skill = input('>')
print(f"Filtering Out {unfamiliar_skill}")

html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
soup = BeautifulSoup(html_text, 'lxml')
jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')
for job in jobs:
    
    published_date = job.find('span', class_ = 'sim-posted').text
    if 'few' in published_date:
        company_name = job.find('h3', class_ = 'joblist-comp-name').text
        skills = job.find('span', class_ = 'srp-skills').text.replace('  , ',',').replace('    ','')
        more_info = job.header.h2.a['href']
        if unfamiliar_skill not in skills:
        
            print(f"Company Name: {company_name.strip()}") 
            print(f"Required Skills: {skills.strip()}")
            print(f"More Info: {more_info}")
            print('')
# Out:
# Put some skill that you are not familiar with
# > linux
# Filtering Out linux
# Company Name: Radical Tecnologies
#      (More Jobs)
# Required Skills: "PYTHON SCRIPTING", "PYTHON", "FULLSTACK  PYTHON"
# More Info: https://www.timesjobs.com/job-detail/python-radical-tecnologies-cochin-kochi-ernakulam-thiruvananthapuram-thrissur-7-to-12-yrs-jobid-bUxdpY7jo5dzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name: learntek
#      (More Jobs)
# Required Skills: Python
# More Info: https://www.timesjobs.com/job-detail/python-faculty-learntek-bengaluru-bangalore-chennai-hyderabad-secunderabad-vijayawada-visakhapatnam-2-to-7-yrs-jobid-K4__PLUS__N8nfOlV5zpSvf__PLUS__uAgZw==&source=srp
#
# Company Name: Ivan Infotech Pvt. Ltd.
# Required Skills: rest, python, security, debugging
# More Info: https://www.timesjobs.com/job-detail/python-developer-ivan-infotech-pvt-ltd-kolkata-2-to-5-yrs-jobid-1h6sLaqbaBZzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name: east india securities ltd.
# ...

# %% [markdown]
# As we can see all the job post above do not have linux as a required skills. As a good activity it would be nice if we can put more than one unfamiliar skill to filter out the job post.

# %%
# next we create a function pulling information from website
import time

print("Put some skill that you are not familiar with")
unfamiliar_skill = input('>')
print(f"Filtering Out {unfamiliar_skill}")

def find_jobs():
    html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
    soup = BeautifulSoup(html_text, 'lxml')
    jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')
    for job in jobs:
    
        published_date = job.find('span', class_ = 'sim-posted').text
        if 'few' in published_date:
            company_name = job.find('h3', class_ = 'joblist-comp-name').text
            skills = job.find('span', class_ = 'srp-skills').text.replace('  , ',',').replace('    ','')
            more_info = job.header.h2.a['href']
            if unfamiliar_skill not in skills:
            
                print(f"Company Name: {company_name.strip()}") 
                print(f"Required Skills: {skills.strip()}")
                print(f"More Info: {more_info}")
                print('')
                
if __name__ == '__main__':
    while True:
        find_jobs()
        time_wait = 10
        print(f'Waiting {time_wait} minutes...')
        time.sleep(time_wait * 60)  # 600 seconds
# Out:
# Put some skill that you are not familiar with
# > django
# Filtering Out django
# Company Name: Radical Tecnologies
#      (More Jobs)
# Required Skills: "PYTHON SCRIPTING", "PYTHON", "FULLSTACK  PYTHON"
# More Info: https://www.timesjobs.com/job-detail/python-radical-tecnologies-cochin-kochi-ernakulam-thiruvananthapuram-thrissur-7-to-12-yrs-jobid-bUxdpY7jo5dzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name: Surya Informatics Solutions Pvt. Ltd.
# Required Skills: python, web technologies, linux, mobile, mysql, angularjs, javascript
# More Info: https://www.timesjobs.com/job-detail/python-surya-informatics-solutions-pvt-ltd-chennai-0-to-3-yrs-jobid-UVlLes58wutzpSvf__PLUS__uAgZw==&source=srp
#
# Company Name: learntek
#      (More Jobs)
# Required Skills: Python
# More Info: https://www.timesjobs.com/job-detail/python-faculty-learntek-bengaluru-bangalore-chennai-hyderabad-secunderabad-vijayawada-visakhapatnam-2-to-7-yrs-jobid-K4__PLUS__N8nfOlV5zpSvf__PLUS__uAgZw==&source=srp
#
# ...

# %%
# next we create a folder with text files of each job description


print("Put some skill that you are not familiar with")
unfamiliar_skill = input('>')
print(f"Filtering Out {unfamiliar_skill}")

def find_jobs():
    html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=').text
    soup = BeautifulSoup(html_text, 'lxml')
    jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')
    for index, job in enumerate(jobs):
    
        published_date = job.find('span', class_ = 'sim-posted').text
        if 'few' in published_date:
            company_name = job.find('h3', class_ = 'joblist-comp-name').text
            skills = job.find('span', class_ = 'srp-skills').text.replace('  , ',',').replace('    ','')
            more_info = job.header.h2.a['href']
            if unfamiliar_skill not in skills:
                with open(f'posts/{index}.txt', 'w') as f:
                    f.write(f"Company Name: {company_name.strip()} \n") 
                    f.write(f"Required Skills: {skills.strip()} \n")
                    f.write(f"More Info: {more_info}")
                print(f'File Saved: {index}')
                
if __name__ == '__main__':
    while True:
        find_jobs()
        time_wait = 10
        print(f'Waiting {time_wait} minutes...')
        time.sleep(time_wait * 60)  # 600 seconds
# Out:
# Put some skill that you are not familiar with
# > linux
# Filtering Out linux
# File Saved: 0
# File Saved: 2
# File Saved: 5
# File Saved: 8
# File Saved: 10
# File Saved: 11
# File Saved: 12
# File Saved: 13
# File Saved: 14
# File Saved: 15
# File Saved: 18
# File Saved: 19
# File Saved: 20
# File Saved: 21
# File Saved: 22
# File Saved: 24
# Waiting 10 minutes...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[101], line 31
#      29 time_wait = 10
#      30 print(f'Waiting {time_wait} minutes...')
# ---> 31 time.sleep(time_wait * 60)
#
# KeyboardInterrupt:
